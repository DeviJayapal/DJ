# %%
import pandas as pd

# %%
D1=pd.read_csv('/content/Electric_Vehicle_Population_Data.csv')

# %%
D1
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0       5YJ3E1EBXK       King       Seattle    WA      98178.0        2019
# 1       5YJYGDEE3L     Kitsap       Poulsbo    WA      98370.0        2020
# 2       KM8KRDAF5P     Kitsap        Olalla    WA      98359.0        2023
# 3       5UXTA6C0XM     Kitsap       Seabeck    WA      98380.0        2021
# 4       JTMAB3FV7P   Thurston       Rainier    WA      98576.0        2023
# ...            ...        ...           ...   ...          ...         ...
# 235687  1C4RJXN62R     Pierce        Tacoma    WA      98407.0        2024
# 235688  5YJSA1E28J  Snohomish      Stanwood    WA      98292.0        2018
# 235689  3FA6P0SU2F       King       Redmond    WA      98052.0        2015
# 235690  WA1BCBFZ6P  Snohomish  Lake Stevens    WA      98258.0        2023
# 235691  WBY33AW03P       King      Issaquah    WA      98027.0        2023
#
#            Make       Model                   Electric Vehicle Type  \
# 0         TESLA     MODEL 3          Battery Electric Vehicle (BEV)
# 1         TESLA     MODEL Y          Battery Electric Vehicle (BEV)
# 2       HYUNDAI     IONIQ 5          Battery Electric Vehicle (BEV)
# 3           BMW          X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 4        TOYOTA  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# ...         ...         ...                                     ...
# 235687     JEEP    WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 235688    TESLA     MODEL S          Battery Electric Vehicle (BEV)
# 235689     FORD      FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 235690     AUDI          Q4          Battery Electric Vehicle (BEV)
# 235691      BMW          I4          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                 Clean Alternative Fuel Vehicle Eligible           220.0
# 1                 Clean Alternative Fuel Vehicle Eligible           291.0
# 2       Eligibility unknown as battery range has not b...             0.0
# 3                 Clean Alternative Fuel Vehicle Eligible            30.0
# 4                 Clean Alternative Fuel Vehicle Eligible            42.0
# ...                                                   ...             ...
# 235687              Not eligible due to low battery range            21.0
# 235688            Clean Alternative Fuel Vehicle Eligible           249.0
# 235689              Not eligible due to low battery range            19.0
# 235690  Eligibility unknown as battery range has not b...             0.0
# 235691  Eligibility unknown as battery range has not b...             0.0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0             0.0                  37.0       477309682
# 1             0.0                  23.0       109705683
# 2             0.0                  26.0       230390492
# 3             0.0                  35.0       267929112
# 4             0.0                   2.0       236505139
# ...           ...                   ...             ...
# 235687        0.0                  27.0       267004272
# 235688        0.0                  10.0       198794410
# 235689        0.0                  48.0       261742288
# 235690        0.0                  44.0       253474854
# 235691        0.0                   5.0       229583490
#
#                    Vehicle Location  \
# 0       POINT (-122.23825 47.49461)
# 1       POINT (-122.64681 47.73689)
# 2       POINT (-122.54729 47.42602)
# 3       POINT (-122.81585 47.64509)
# 4       POINT (-122.68993 46.88897)
# ...                             ...
# 235687  POINT (-122.51134 47.29238)
# 235688  POINT (-122.37265 48.24159)
# 235689  POINT (-122.13158 47.67858)
# 235690  POINT (-122.06402 48.01497)
# 235691   POINT (-122.03439 47.5301)
#
#                                          Electric Utility  2020 Census Tract
# 0            CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 1                                  PUGET SOUND ENERGY INC       5.303509e+10
# 2                                  PUGET SOUND ENERGY INC       5.303509e+10
# 3                                  PUGET SOUND ENERGY INC       5.303509e+10
# 4                                  PUGET SOUND ENERGY INC       5.306701e+10
# ...                                                   ...                ...
# 235687  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305306e+10
# 235688  BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOH...       5.306105e+10
# 235689      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 235690                             PUGET SOUND ENERGY INC       5.306105e+10
# 235691      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
#
# [235692 rows x 17 columns]

# %%
D1.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  235689.000000  235692.000000   235656.000000  235656.000000
# mean    98177.656463    2021.406658       46.262569     787.268328
# std      2524.218661       2.991908       84.045829    7177.668305
# min      1731.000000    2000.000000        0.000000       0.000000
# 25%     98052.000000    2020.000000        0.000000       0.000000
# 50%     98126.000000    2023.000000        0.000000       0.000000
# 75%     98374.000000    2024.000000       38.000000       0.000000
# max     99577.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         235198.000000    2.356920e+05       2.356890e+05
# mean              28.879519    2.353127e+08       5.298066e+10
# std               14.904644    6.799098e+07       1.521066e+09
# min                1.000000    4.385000e+03       1.001020e+09
# 25%               17.000000    2.053457e+08       5.303301e+10
# 50%               32.000000    2.522795e+08       5.303303e+10
# 75%               42.000000    2.696401e+08       5.305307e+10
# max               49.000000    4.792548e+08       5.602100e+10

# %%
D1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235692 entries, 0 to 235691
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         235692 non-null  object
#  1   County                                             235689 non-null  object
#  2   City                                               235689 non-null  object
#  3   State                                              235692 non-null  object
#  4   Postal Code                                        235689 non-null  float64
#  5   Model Year                                         235692 non-null  int64
#  6   Make                                               235692 non-null  object
#  7   Model                                              235692 non-null  object
#  8   Electric Vehicle Type                              235692 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  235692 non-null  object
#  10  Electric Range                                     235656 non-null  float64
#  11  Base MSRP                                          235656 non-null  float64
#  12  Legislative District                               235198 non-null  float64
#  13  DOL Vehicle ID                                     235692 non-null  int64
#  14  Vehicle Location                                   235682 non-null  object
#  15  Electric Utility                                   235689 non-null  object
#  16  2020 Census Tract                                  235689 non-null  float64
# dtypes: float64(5), int64(2), object(10)
# memory usage: 30.6+ MB

# %%
D1.shape
# Out:
# (235692, 17)

# %%
D1.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
D1.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                       float64
# Base MSRP                                            float64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# Electric Utility                                      object
# 2020 Census Tract                                    float64
# dtype: object

# %%
D1.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year     Make  \
# 0  5YJ3E1EBXK      King  Seattle    WA      98178.0        2019    TESLA
# 1  5YJYGDEE3L    Kitsap  Poulsbo    WA      98370.0        2020    TESLA
# 2  KM8KRDAF5P    Kitsap   Olalla    WA      98359.0        2023  HYUNDAI
# 3  5UXTA6C0XM    Kitsap  Seabeck    WA      98380.0        2021      BMW
# 4  JTMAB3FV7P  Thurston  Rainier    WA      98576.0        2023   TOYOTA
#
#         Model                   Electric Vehicle Type  \
# 0     MODEL 3          Battery Electric Vehicle (BEV)
# 1     MODEL Y          Battery Electric Vehicle (BEV)
# 2     IONIQ 5          Battery Electric Vehicle (BEV)
# 3          X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 4  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible           220.0
# 1            Clean Alternative Fuel Vehicle Eligible           291.0
# 2  Eligibility unknown as battery range has not b...             0.0
# 3            Clean Alternative Fuel Vehicle Eligible            30.0
# 4            Clean Alternative Fuel Vehicle Eligible            42.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  37.0       477309682
# 1        0.0                  23.0       109705683
# 2        0.0                  26.0       230390492
# 3        0.0                  35.0       267929112
# 4        0.0                   2.0       236505139
#
#               Vehicle Location                              Electric Utility  \
# 0  POINT (-122.23825 47.49461)  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 1  POINT (-122.64681 47.73689)                        PUGET SOUND ENERGY INC
# 2  POINT (-122.54729 47.42602)                        PUGET SOUND ENERGY INC
# 3  POINT (-122.81585 47.64509)                        PUGET SOUND ENERGY INC
# 4  POINT (-122.68993 46.88897)                        PUGET SOUND ENERGY INC
#
#    2020 Census Tract
# 0       5.303301e+10
# 1       5.303509e+10
# 2       5.303509e+10
# 3       5.303509e+10
# 4       5.306701e+10

# %%
D1[['Model','Make','State']]
# Out:
#              Model     Make State
# 0          MODEL 3    TESLA    WA
# 1          MODEL Y    TESLA    WA
# 2          IONIQ 5  HYUNDAI    WA
# 3               X5      BMW    WA
# 4       RAV4 PRIME   TOYOTA    WA
# ...            ...      ...   ...
# 235687    WRANGLER     JEEP    WA
# 235688     MODEL S    TESLA    WA
# 235689      FUSION     FORD    WA
# 235690          Q4     AUDI    WA
# 235691          I4      BMW    WA
#
# [235692 rows x 3 columns]

# %%
D1.iloc[5000]
# Out:
# VIN (1-10)                                                                                  7SAYGAEE5P
# County                                                                                            King
# City                                                                                          Bellevue
# State                                                                                               WA
# Postal Code                                                                                    98006.0
# Model Year                                                                                        2023
# Make                                                                                             TESLA
# Model                                                                                          MODEL Y
# Electric Vehicle Type                                                   Battery Electric Vehicle (BEV)
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    Eligibility unknown as battery range has not b...
# Electric Range                                                                                     0.0
# Base MSRP                                                                                          0.0
# Legislative District                                                                              41.0
# DOL Vehicle ID                                                                               252282586
# Vehicle Location                                                           POINT (-122.12096 47.55584)
# Electric Utility                                         PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 2020 Census Tract                                                                        53033024800.0
# Name: 5000, dtype: object

# %%
D1.iloc[150476,6]
# Out:
# 'FORD'

# %%
print(D1.loc[6,'Make'])
# Out:
# BMW

# %%
D1.loc[2001,['Make','City']]
# Out:
# Make        BMW
# City    Bothell
# Name: 2001, dtype: object

# %%
D1[D1['Model Year']>2020]
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 2       KM8KRDAF5P     Kitsap        Olalla    WA      98359.0        2023
# 3       5UXTA6C0XM     Kitsap       Seabeck    WA      98380.0        2021
# 4       JTMAB3FV7P   Thurston       Rainier    WA      98576.0        2023
# 7       3MW5P9J0XN  Snohomish    Marysville    WA      98271.0        2022
# 13      LPSED3KA8M       King       Seattle    WA      98125.0        2021
# ...            ...        ...           ...   ...          ...         ...
# 235684  WA1F2AFY7M    Whatcom        Blaine    WA      98230.0        2021
# 235686  7SAYGDEE2P       King       Seattle    WA      98109.0        2023
# 235687  1C4RJXN62R     Pierce        Tacoma    WA      98407.0        2024
# 235690  WA1BCBFZ6P  Snohomish  Lake Stevens    WA      98258.0        2023
# 235691  WBY33AW03P       King      Issaquah    WA      98027.0        2023
#
#             Make       Model                   Electric Vehicle Type  \
# 2        HYUNDAI     IONIQ 5          Battery Electric Vehicle (BEV)
# 3            BMW          X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 4         TOYOTA  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 7            BMW        330E  Plug-in Hybrid Electric Vehicle (PHEV)
# 13      POLESTAR         PS2          Battery Electric Vehicle (BEV)
# ...          ...         ...                                     ...
# 235684      AUDI        Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
# 235686     TESLA     MODEL Y          Battery Electric Vehicle (BEV)
# 235687      JEEP    WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 235690      AUDI          Q4          Battery Electric Vehicle (BEV)
# 235691       BMW          I4          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 2       Eligibility unknown as battery range has not b...             0.0
# 3                 Clean Alternative Fuel Vehicle Eligible            30.0
# 4                 Clean Alternative Fuel Vehicle Eligible            42.0
# 7                   Not eligible due to low battery range            22.0
# 13                Clean Alternative Fuel Vehicle Eligible           233.0
# ...                                                   ...             ...
# 235684              Not eligible due to low battery range            18.0
# 235686  Eligibility unknown as battery range has not b...             0.0
# 235687              Not eligible due to low battery range            21.0
# 235690  Eligibility unknown as battery range has not b...             0.0
# 235691  Eligibility unknown as battery range has not b...             0.0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 2             0.0                  26.0       230390492
# 3             0.0                  35.0       267929112
# 4             0.0                   2.0       236505139
# 7             0.0                  39.0       204822761
# 13            0.0                  46.0       183391526
# ...           ...                   ...             ...
# 235684        0.0                  42.0       171206003
# 235686        0.0                  36.0       272885581
# 235687        0.0                  27.0       267004272
# 235690        0.0                  44.0       253474854
# 235691        0.0                   5.0       229583490
#
#                    Vehicle Location  \
# 2       POINT (-122.54729 47.42602)
# 3       POINT (-122.81585 47.64509)
# 4       POINT (-122.68993 46.88897)
# 7        POINT (-122.1677 48.11026)
# 13      POINT (-122.30253 47.72656)
# ...                             ...
# 235684  POINT (-122.74888 48.99404)
# 235686  POINT (-122.35022 47.63824)
# 235687  POINT (-122.51134 47.29238)
# 235690  POINT (-122.06402 48.01497)
# 235691   POINT (-122.03439 47.5301)
#
#                                          Electric Utility  2020 Census Tract
# 2                                  PUGET SOUND ENERGY INC       5.303509e+10
# 3                                  PUGET SOUND ENERGY INC       5.303509e+10
# 4                                  PUGET SOUND ENERGY INC       5.306701e+10
# 7                                  PUGET SOUND ENERGY INC       5.306105e+10
# 13           CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# ...                                                   ...                ...
# 235684  CITY OF BLAINE - (WA)||PUD NO 1 OF WHATCOM COUNTY       5.307301e+10
# 235686       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 235687  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305306e+10
# 235690                             PUGET SOUND ENERGY INC       5.306105e+10
# 235691      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
#
# [169686 rows x 17 columns]

# %%
D1[D1['Model Year']>2020 & (D1['Electric Range']>200)]
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0       5YJ3E1EBXK       King       Seattle    WA      98178.0        2019
# 1       5YJYGDEE3L     Kitsap       Poulsbo    WA      98370.0        2020
# 2       KM8KRDAF5P     Kitsap        Olalla    WA      98359.0        2023
# 3       5UXTA6C0XM     Kitsap       Seabeck    WA      98380.0        2021
# 4       JTMAB3FV7P   Thurston       Rainier    WA      98576.0        2023
# ...            ...        ...           ...   ...          ...         ...
# 235687  1C4RJXN62R     Pierce        Tacoma    WA      98407.0        2024
# 235688  5YJSA1E28J  Snohomish      Stanwood    WA      98292.0        2018
# 235689  3FA6P0SU2F       King       Redmond    WA      98052.0        2015
# 235690  WA1BCBFZ6P  Snohomish  Lake Stevens    WA      98258.0        2023
# 235691  WBY33AW03P       King      Issaquah    WA      98027.0        2023
#
#            Make       Model                   Electric Vehicle Type  \
# 0         TESLA     MODEL 3          Battery Electric Vehicle (BEV)
# 1         TESLA     MODEL Y          Battery Electric Vehicle (BEV)
# 2       HYUNDAI     IONIQ 5          Battery Electric Vehicle (BEV)
# 3           BMW          X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 4        TOYOTA  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# ...         ...         ...                                     ...
# 235687     JEEP    WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 235688    TESLA     MODEL S          Battery Electric Vehicle (BEV)
# 235689     FORD      FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 235690     AUDI          Q4          Battery Electric Vehicle (BEV)
# 235691      BMW          I4          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                 Clean Alternative Fuel Vehicle Eligible           220.0
# 1                 Clean Alternative Fuel Vehicle Eligible           291.0
# 2       Eligibility unknown as battery range has not b...             0.0
# 3                 Clean Alternative Fuel Vehicle Eligible            30.0
# 4                 Clean Alternative Fuel Vehicle Eligible            42.0
# ...                                                   ...             ...
# 235687              Not eligible due to low battery range            21.0
# 235688            Clean Alternative Fuel Vehicle Eligible           249.0
# 235689              Not eligible due to low battery range            19.0
# 235690  Eligibility unknown as battery range has not b...             0.0
# 235691  Eligibility unknown as battery range has not b...             0.0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0             0.0                  37.0       477309682
# 1             0.0                  23.0       109705683
# 2             0.0                  26.0       230390492
# 3             0.0                  35.0       267929112
# 4             0.0                   2.0       236505139
# ...           ...                   ...             ...
# 235687        0.0                  27.0       267004272
# 235688        0.0                  10.0       198794410
# 235689        0.0                  48.0       261742288
# 235690        0.0                  44.0       253474854
# 235691        0.0                   5.0       229583490
#
#                    Vehicle Location  \
# 0       POINT (-122.23825 47.49461)
# 1       POINT (-122.64681 47.73689)
# 2       POINT (-122.54729 47.42602)
# 3       POINT (-122.81585 47.64509)
# 4       POINT (-122.68993 46.88897)
# ...                             ...
# 235687  POINT (-122.51134 47.29238)
# 235688  POINT (-122.37265 48.24159)
# 235689  POINT (-122.13158 47.67858)
# 235690  POINT (-122.06402 48.01497)
# 235691   POINT (-122.03439 47.5301)
#
#                                          Electric Utility  2020 Census Tract
# 0            CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 1                                  PUGET SOUND ENERGY INC       5.303509e+10
# 2                                  PUGET SOUND ENERGY INC       5.303509e+10
# 3                                  PUGET SOUND ENERGY INC       5.303509e+10
# 4                                  PUGET SOUND ENERGY INC       5.306701e+10
# ...                                                   ...                ...
# 235687  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305306e+10
# 235688  BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOH...       5.306105e+10
# 235689      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 235690                             PUGET SOUND ENERGY INC       5.306105e+10
# 235691      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
#
# [235692 rows x 17 columns]

# %%
D1.query("Make =='AUDI' and Model == 'E-TRON' ")
# Out:
#         VIN (1-10)     County       City State  Postal Code  Model Year  Make  \
# 111     WA11AAGE6P   Thurston      Lacey    WA      98516.0        2023  AUDI
# 293     WA1AAAGE4M  Snohomish   Lynnwood    WA      98036.0        2021  AUDI
# 353     WA1VCBGE7N       King  Sammamish    WA      98074.0        2022  AUDI
# 463     WA1AAAGE4M       King  Newcastle    WA      98059.0        2021  AUDI
# 620     WA1LABGE5M       King   Bellevue    WA      98007.0        2021  AUDI
# ...            ...        ...        ...   ...          ...         ...   ...
# 234696  WA1VABGE1K  Snohomish  Snohomish    WA      98290.0        2019  AUDI
# 234832  WA1AAAGE3N   San Juan  Eastsound    WA      98245.0        2022  AUDI
# 235481  WA1VABGE0N     Kitsap  Bremerton    WA      98312.0        2022  AUDI
# 235539  WA1LAAGE7N  Snohomish   Lynnwood    WA      98087.0        2022  AUDI
# 235588  WA1AAAGE7M    Spokane    Spokane    WA      99203.0        2021  AUDI
#
#          Model           Electric Vehicle Type  \
# 111     E-TRON  Battery Electric Vehicle (BEV)
# 293     E-TRON  Battery Electric Vehicle (BEV)
# 353     E-TRON  Battery Electric Vehicle (BEV)
# 463     E-TRON  Battery Electric Vehicle (BEV)
# 620     E-TRON  Battery Electric Vehicle (BEV)
# ...        ...                             ...
# 234696  E-TRON  Battery Electric Vehicle (BEV)
# 234832  E-TRON  Battery Electric Vehicle (BEV)
# 235481  E-TRON  Battery Electric Vehicle (BEV)
# 235539  E-TRON  Battery Electric Vehicle (BEV)
# 235588  E-TRON  Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 111     Eligibility unknown as battery range has not b...             0.0
# 293               Clean Alternative Fuel Vehicle Eligible           222.0
# 353     Eligibility unknown as battery range has not b...             0.0
# 463               Clean Alternative Fuel Vehicle Eligible           222.0
# 620     Eligibility unknown as battery range has not b...             0.0
# ...                                                   ...             ...
# 234696            Clean Alternative Fuel Vehicle Eligible           204.0
# 234832  Eligibility unknown as battery range has not b...             0.0
# 235481  Eligibility unknown as battery range has not b...             0.0
# 235539  Eligibility unknown as battery range has not b...             0.0
# 235588            Clean Alternative Fuel Vehicle Eligible           222.0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 111           0.0                  22.0       220334880
# 293           0.0                   1.0       261916875
# 353           0.0                  45.0       227232050
# 463           0.0                  41.0       148381264
# 620           0.0                  41.0       274223533
# ...           ...                   ...             ...
# 234696        0.0                  39.0       125706787
# 234832        0.0                  40.0       207314040
# 235481        0.0                  35.0       241374976
# 235539        0.0                  21.0       205031501
# 235588        0.0                   3.0       205740608
#
#                    Vehicle Location  \
# 111     POINT (-122.75103 47.08149)
# 293     POINT (-122.29245 47.82557)
# 353     POINT (-122.02054 47.60326)
# 463     POINT (-122.15734 47.48718)
# 620     POINT (-122.12056 47.61334)
# ...                             ...
# 234696  POINT (-122.09305 47.91265)
# 234832  POINT (-122.91109 48.69389)
# 235481   POINT (-122.6563 47.56739)
# 235539  POINT (-122.27981 47.85727)
# 235588  POINT (-117.39322 47.63374)
#
#                                          Electric Utility  2020 Census Tract
# 111                                PUGET SOUND ENERGY INC       5.306701e+10
# 293                                PUGET SOUND ENERGY INC       5.306105e+10
# 353         PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 463         PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 620         PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# ...                                                   ...                ...
# 234696                             PUGET SOUND ENERGY INC       5.306105e+10
# 234832  BONNEVILLE POWER ADMINISTRATION||ORCAS POWER &...       5.305596e+10
# 235481                             PUGET SOUND ENERGY INC       5.303508e+10
# 235539                             PUGET SOUND ENERGY INC       5.306104e+10
# 235588                      MODERN ELECTRIC WATER COMPANY       5.306300e+10
#
# [1067 rows x 17 columns]

# %%
D1.rename(columns={'Electric Range': 'EleRa'}, inplace=True)

# %%
D1.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# EleRa                                                 36
# Base MSRP                                             36
# Legislative District                                 494
# DOL Vehicle ID                                         0
# Vehicle Location                                      10
# Electric Utility                                       3
# 2020 Census Tract                                      3
# dtype: int64

# %%
D1['Legislative District'].fillna(D1['Legislative District'].mean(),inplace=True)
# Out:
# <ipython-input-24-699530360>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   D1['Legislative District'].fillna(D1['Legislative District'].mean(),inplace=True)

# %%
D1.isnull().sum()
# Out:
# VIN (1-10)                                            0
# County                                                3
# City                                                  3
# State                                                 0
# Postal Code                                           3
# Model Year                                            0
# Make                                                  0
# Model                                                 0
# Electric Vehicle Type                                 0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     0
# EleRa                                                36
# Base MSRP                                            36
# Legislative District                                  0
# DOL Vehicle ID                                        0
# Vehicle Location                                     10
# Electric Utility                                      3
# 2020 Census Tract                                     3
# dtype: int64

# %%
D1.drop(3,axis=0,inplace=True)

# %%
D1.sort_values(by='Model Year',ascending=False, inplace=True)
D1
# Out:
#         VIN (1-10)     County           City State  Postal Code  Model Year  \
# 127001  3GN7DLRP5S       King    Federal Way    WA      98003.0        2025
# 127000  7SAYGAEE9S       King        Seattle    WA      98115.0        2025
# 201071  7PDSGCBP5S       King      Sammamish    WA      98074.0        2025
# 225534  7SAYGDEE4S  Snohomish   Lake Stevens    WA      98258.0        2025
# 201043  KNDPYDDH6S     Chelan    Leavenworth    WA      98826.0        2025
# ...            ...        ...            ...   ...          ...         ...
# 76567   1FTZR0817Y       King        Seattle    WA      98117.0        2000
# 59048   1FTZR0816Y   Thurston        Olympia    WA      98506.0        2000
# 216581  1FTZR0870Y   San Juan  Friday Harbor    WA      98250.0        2000
# 143805  1FTZR0813Y    Whatcom        Everson    WA      98247.0        2000
# 182703  1FTZR0879Y    Whatcom        Everson    WA      98247.0        2000
#
#              Make       Model                   Electric Vehicle Type  \
# 127001  CHEVROLET  EQUINOX EV          Battery Electric Vehicle (BEV)
# 127000      TESLA     MODEL Y          Battery Electric Vehicle (BEV)
# 201071     RIVIAN         R1S          Battery Electric Vehicle (BEV)
# 225534      TESLA     MODEL Y          Battery Electric Vehicle (BEV)
# 201043        KIA    SPORTAGE  Plug-in Hybrid Electric Vehicle (PHEV)
# ...           ...         ...                                     ...
# 76567        FORD      RANGER          Battery Electric Vehicle (BEV)
# 59048        FORD      RANGER          Battery Electric Vehicle (BEV)
# 216581       FORD      RANGER          Battery Electric Vehicle (BEV)
# 143805       FORD      RANGER          Battery Electric Vehicle (BEV)
# 182703       FORD      RANGER          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  EleRa  Base MSRP  \
# 127001  Eligibility unknown as battery range has not b...    0.0        0.0
# 127000  Eligibility unknown as battery range has not b...    0.0        0.0
# 201071  Eligibility unknown as battery range has not b...    0.0        0.0
# 225534  Eligibility unknown as battery range has not b...    0.0        0.0
# 201043            Clean Alternative Fuel Vehicle Eligible   34.0        0.0
# ...                                                   ...    ...        ...
# 76567             Clean Alternative Fuel Vehicle Eligible   58.0        0.0
# 59048             Clean Alternative Fuel Vehicle Eligible   58.0        0.0
# 216581            Clean Alternative Fuel Vehicle Eligible   58.0        0.0
# 143805            Clean Alternative Fuel Vehicle Eligible   58.0        0.0
# 182703            Clean Alternative Fuel Vehicle Eligible   58.0        0.0
#
#         Legislative District  DOL Vehicle ID             Vehicle Location  \
# 127001                  30.0       275903512   POINT (-122.3303 47.30151)
# 127000                  46.0       274158055  POINT (-122.31676 47.68156)
# 201071                  45.0       276810523  POINT (-122.02054 47.60326)
# 225534                  44.0       276827400  POINT (-122.06402 48.01497)
# 201043                  12.0       273664268   POINT (-120.65754 47.5982)
# ...                      ...             ...                          ...
# 76567                   36.0       142611402  POINT (-122.38418 47.70044)
# 59048                   22.0         8166497  POINT (-122.87741 47.05997)
# 216581                  40.0       221693048  POINT (-123.01648 48.53448)
# 143805                  42.0         8650316  POINT (-122.34527 48.92009)
# 182703                  42.0       122864766  POINT (-122.34527 48.92009)
#
#                                          Electric Utility  2020 Census Tract
# 127001      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 127000       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 201071      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 225534                             PUGET SOUND ENERGY INC       5.306105e+10
# 201043                          PUD NO 1 OF CHELAN COUNTY       5.300796e+10
# ...                                                   ...                ...
# 76567        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 59048                              PUGET SOUND ENERGY INC       5.306701e+10
# 216581  BONNEVILLE POWER ADMINISTRATION||ORCAS POWER &...       5.305596e+10
# 143805  PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM CO...       5.307301e+10
# 182703  PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM CO...       5.307301e+10
#
# [235691 rows x 17 columns]

# %%
D1.groupby(['Make','Model'])['EleRa'].sum()
# Out:
# Make                  Model
# ACURA                 ZDX           0.0
# ALFA ROMEO            TONALE     3201.0
# AUDI                  A3         8864.0
#                       A7 E        312.0
#                       A8 E         51.0
#                                  ...
# VOLVO                 V60        3503.0
#                       XC40          0.0
#                       XC60      44489.0
#                       XC90      49311.0
# WHEEGO ELECTRIC CARS  WHEEGO      200.0
# Name: EleRa, Length: 171, dtype: float64
